# %%
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
import numpy as np
import pandas as pd
import seaborn
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
jeux=pd.read_csv('C:/Users/ludo1/Python for Data analysis/TD1/Video_Games_Sales_as_at_22_Dec_2016.csv',error_bad_lines=False ,dtype=None, sep=",")
# Out:
# b'Skipping line 950: expected 16 fields, saw 17\nSkipping line 1091: expected 16 fields, saw 17\nSkipping line 1633: expected 16 fields, saw 17\nSkipping line 1839: expected 16 fields, saw 19\nSkipping line 2888: expected 16 fields, saw 17\nSkipping line 2945: expected 16 fields, saw 18\nSkipping line 3026: expected 16 fields, saw 17\nSkipping line 3105: expected 16 fields, saw 19\nSkipping line 3218: expected 16 fields, saw 18\nSkipping line 3355: expected 16 fields, saw 19\nSkipping line 3447: expected 16 fields, saw 18\nSkipping line 3512: expected 16 fields, saw 19\nSkipping line 3567: expected 16 fields, saw 17\nSkipping line 3568: expected 16 fields, saw 17\nSkipping line 3745: expected 16 fields, saw 17\nSkipping line 3905: expected 16 fields, saw 18\nSkipping line 3976: expected 16 fields, saw 18\nSkipping line 4059: expected 16 fields, saw 18\nSkipping line 4108: expected 16 fields, saw 18\nSkipping line 4181: expected 16 fields, saw 17\nSkipping line 4377: expected 16 field
# ...

# %%
jeux
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16605  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16606               LMA Manager 2007     X360           2006.0        Sports
# 16607        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16608               Spirits & Spells      GBA           2003.0      Platform
# 16609            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [raw]
# Cette base de donnée regroupe tout les données concernant plus 16000 jeux vidéo entre 1980 et 2016
#
# Crit score : le score donnée par les journaliste
# Crit count : nombre de journaliste ayant fait la crititique
# User score:le score donnée par les joueurs
# User count : nombre de joueur ayant fait la critique
# Nome_Sales: nombre de vente faite dans une régions ou dans le monde (en million)
# Rating : équivaut à l'ESRB  : en outre à quel catégorie de client est il destiné ( teen, mature ect...)
# provenance de la base de données :
# https://www.kaggle.com/sidtwr/videogames-sales-dataset?select=Video_Games_Sales_as_at_22_Dec_2016.csv
# La base de donnée est la fusion du site web  VGChartz Video Games Sales et le site web metaCritic

# %%
jeux.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Developer           object
# Rating;             object
# dtype: object

# %%
# En regardant rapidement la base de donnée on se rend compte que pas mal de jeux on des donnée manquantes nous allons donc conserver seulement les jeux ayant toute leurs informations
jeux2=jeux
jeux=jeux.dropna()
jeux
# Nous conservons donc à la fin environ 6500 jeux
# Out:
#                                     Name Platform  Year_of_Release      Genre  \
# 0                             Wii Sports      Wii           2006.0     Sports
# 2                         Mario Kart Wii      Wii           2008.0     Racing
# 3                      Wii Sports Resort      Wii           2009.0     Sports
# 6                  New Super Mario Bros.       DS           2006.0   Platform
# 7                               Wii Play      Wii           2006.0       Misc
# ...                                  ...      ...              ...        ...
# 16568     Mortal Kombat: Deadly Alliance      GBA           2002.0   Fighting
# 16587  Metal Gear Solid V: Ground Zeroes       PC           2014.0     Action
# 16591                             Breach       PC           2011.0    Shooter
# 16597            STORM: Frontline Nation       PC           2011.0   Strategy
# 16600                            15 Days       PC           2009.0  Adventure
#
# ...

# %% [markdown]
# # Analyse rapide

# %%
#Quel sont les  ventes de jeux  de la WII PS2 X360
top100=jeux.sort_values(by="Global_Sales")
VenteAP=jeux.pivot_table('Global_Sales',index="Year_of_Release",columns="Platform",aggfunc=sum)
VenteAP
# Out:
# Platform           3DS    DC     DS    GBA     GC     PC     PS     PS2  \
# Year_of_Release
# 1988.0             NaN   NaN    NaN    NaN    NaN   0.03    NaN     NaN
# 1992.0             NaN   NaN    NaN    NaN    NaN   0.03    NaN     NaN
# 1994.0             NaN   NaN    NaN    NaN    NaN    NaN   1.27     NaN
# 1996.0             NaN   NaN    NaN    NaN    NaN   1.59  17.73     NaN
# 1997.0             NaN   NaN    NaN    NaN    NaN   4.12  31.90     NaN
# 1998.0             NaN   NaN    NaN    NaN    NaN   0.10  45.14     NaN
# 1999.0             NaN  2.04    NaN    NaN    NaN   0.11  49.02     NaN
# 2000.0             NaN  1.98    NaN    NaN    NaN   3.18  44.12   29.46
# 2001.0             NaN  0.53    NaN  36.63  25.36   5.38  18.15  144.55
# 2002.0             NaN   NaN    NaN  27.76  40.92   8.55   0.11  168.59
# 2003.0             NaN   NaN    NaN  23.83  38.25   6.44    NaN  135.99
# 2004.0             NaN   NaN   3.20  33.27  22.45  10.22    NaN  185.51
# ...

# %%
#Quel sont les ventes total de chaque plateform
fig = plt.figure(1, figsize=(20, 3))
jeux.groupby("Platform").Global_Sales.sum().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Platform'>

# %%
# Quel sont les vente par année de la Wii PS2 et X360
liste=["Wii","PS2","X360"]
subset=VenteAP[liste]
subset.plot(figsize=(15,13),grid=False,title="les ventes de jeux de la Xbox 360 WII et PS2")
# Out:
# <AxesSubplot:title={'center':'les ventes de la Xbox 360 WII et PS2'}, xlabel='Year_of_Release'>

# %%
# Quel sont les meilleur ventes par année
fig = plt.figure(1, figsize=(10, 3))
jeux.groupby("Year_of_Release").Global_Sales.sum().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Year_of_Release'>

# %% [raw]
# on voit bien que la période 2005 -2010 à été une grande période de vente

# %%
#Combien de jeux par ESRB on été vendus chaque année?
VenteYR=jeux.pivot_table('Global_Sales',index="Year_of_Release",columns="Rating;",aggfunc=sum)

# %%
VenteYR.plot(figsize=(15,13),grid=False,title="les ventes de jeux par ERB et par année")
# Out:
# <AxesSubplot:title={'center':'les ventes de jeux par ERB et par année'}, xlabel='Year_of_Release'>

# %% [raw]
# Quand on regarde la Courbre E (soit la courbe pour everyone ) on se rend compte qu'elle atteine son pique en 2007 période ou
# les jeux Wii étaient les plus vendus . Une question peut se poser est ce que ce pique est du au vente de la Wii?

# %%
VenteRP=jeux[jeux.Year_of_Release==2007.0].pivot_table('Name',index="Rating;",columns="Platform",aggfunc='count')

# %%
subset2=VenteRP[liste]
subset2.plot(figsize=(15,13),grid=False,title="les ventes de jeux par ESRB et par platform",kind='bar')
# Out:
# <AxesSubplot:title={'center':'les ventes de jeux par ESRB et par platform'}, xlabel='Rating;'>

# %%
# Quel est la plateform la plus aprécié en moyenne
fig = plt.figure(1, figsize=(10, 3))
jeux.groupby("Platform").User_Score.mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Platform'>
